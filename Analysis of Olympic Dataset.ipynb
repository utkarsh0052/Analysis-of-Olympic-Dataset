# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the Dataset

# %% [markdown]
# ### Winter

# %%
winter = pd.read_csv(r'F:\data science\Analysis of Olympic Dataset\winter.csv')
winter.head(10)
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
# 5  1924  Chamonix  Biathlon   Biathlon       JULEN, Alphonse     SUI    Men
# 6  1924  Chamonix  Biathlon   Biathlon           JULEN, Ant.     SUI    Men
# 7  1924  Chamonix  Biathlon   Biathlon           VAUCHER, D.     SUI    Men
# 8  1924  Chamonix  Biathlon   Biathlon          BREMER, V.E.     FIN    Men
# 9  1924  Chamonix  Biathlon   Biathlon         ESKELINEN, A.     FIN    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold
# 5  Military Patrol    Gold
# 6  Military Patrol    Gold
# 7  Military Patrol    Gold
# 8  Military Patrol  Silver
# 9  Military Patrol  Silver

# %%
winter.tail(10)
# Out:
#       Year   City   Sport Discipline              Athlete Country Gender  \
# 5760  2014  Sochi  Skiing  Snowboard  FARRINGTON, Kaitlyn     USA  Women
# 5761  2014  Sochi  Skiing  Snowboard     DUJMOVITS, Julia     AUT  Women
# 5762  2014  Sochi  Skiing  Snowboard       KARSTENS, Anke     GER  Women
# 5763  2014  Sochi  Skiing  Snowboard        KOBER, Amelie     GER  Women
# 5764  2014  Sochi  Skiing  Snowboard      RUKAJARVI, Enni     FIN  Women
# 5765  2014  Sochi  Skiing  Snowboard         JONES, Jenny     GBR  Women
# 5766  2014  Sochi  Skiing  Snowboard      ANDERSON, Jamie     USA  Women
# 5767  2014  Sochi  Skiing  Snowboard   MALTAIS, Dominique     CAN  Women
# 5768  2014  Sochi  Skiing  Snowboard         SAMKOVA, Eva     CZE  Women
# 5769  2014  Sochi  Skiing  Snowboard     TRESPEUCH, Chloe     FRA  Women
#
#                 Event   Medal
# 5760        Half-Pipe    Gold
# 5761  Parallel Slalom    Gold
# 5762  Parallel Slalom  Silver
# 5763  Parallel Slalom  Bronze
# 5764       Slopestyle  Silver
# 5765       Slopestyle  Bronze
# 5766       Slopestyle    Gold
# 5767  Snowboard Cross  Silver
# 5768  Snowboard Cross    Gold
# 5769  Snowboard Cross  Bronze

# %% [markdown]
# ### Summer

# %%
summer = pd.read_csv(r'F:\data science\Analysis of Olympic Dataset\summer.csv')
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.tail(10)
# Out:
#        Year    City      Sport           Discipline  \
# 31155  2012  London  Wrestling  Wrestling Freestyle
# 31156  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31158  2012  London  Wrestling  Wrestling Freestyle
# 31159  2012  London  Wrestling  Wrestling Freestyle
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                             Athlete Country Gender     Event   Medal
# 31155                 AHMADOV, Emin     AZE    Men  Wg 74 KG  Bronze
# 31156          KAZAKEVIC, Aleksandr     LTU    Men  Wg 74 KG  Bronze
# 31157                 KHUGAEV, Alan     RUS    Men  Wg 84 KG    Gold
# 31158  EBRAHIM, Karam Mohamed Gaber     EGY    Men  Wg 84 KG  Silver
# 31159               GAJIYEV, Danyal     KAZ    Men  Wg 84 KG  Bronze
# 31160            JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161     REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162                TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163             ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164                LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %%
dict = pd.read_csv(r'F:\data science\Analysis of Olympic Dataset\dictionary.csv')
dict.head()
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
dict.tail(10)
# Out:
#              Country Code   Population  GDP per Capita
# 191    United States  USA  321418820.0    56115.718426
# 192          Uruguay  URU    3431555.0    15573.900919
# 193       Uzbekistan  UZB   31299500.0     2132.070368
# 194          Vanuatu  VAN     264652.0     2805.314644
# 195        Venezuela  VEN   31108083.0             NaN
# 196          Vietnam  VIE   91703800.0     2111.138024
# 197  Virgin Islands*  ISV     103574.0             NaN
# 198            Yemen  YEM   26832215.0     1406.291651
# 199           Zambia  ZAM   16211767.0     1304.879014
# 200         Zimbabwe  ZIM   15602751.0      924.143819

# %% [markdown]
# # Analyzing the Winter Data

# %%
winter.rename(columns={'Country':'Code'}, inplace=True)

# %%
winter = pd.merge(winter, dict, on='Code', how='outer')

# %%
winter.head()
# Out:
#      Year      City     Sport Discipline              Athlete Code Gender  \
# 0  1924.0  Chamonix  Biathlon   Biathlon          BERTHET, G.  FRA    Men
# 1  1924.0  Chamonix  Biathlon   Biathlon       MANDRILLON, C.  FRA    Men
# 2  1924.0  Chamonix  Biathlon   Biathlon  MANDRILLON, Maurice  FRA    Men
# 3  1924.0  Chamonix  Biathlon   Biathlon      VANDELLE, André  FRA    Men
# 4  1924.0  Chamonix   Curling    Curling          ALDEERT, H.  FRA    Men
#
#              Event   Medal Country  Population  GDP per Capita
# 0  Military Patrol  Bronze  France  66808385.0    36205.568102
# 1  Military Patrol  Bronze  France  66808385.0    36205.568102
# 2  Military Patrol  Bronze  France  66808385.0    36205.568102
# 3  Military Patrol  Bronze  France  66808385.0    36205.568102
# 4          Curling  Bronze  France  66808385.0    36205.568102

# %%
winter.describe(include='all')
# Out:
#                Year   City   Sport  Discipline                 Athlete  Code  \
# count   5770.000000   5770    5770        5770                    5770  5934
# unique          NaN     19       7          15                    3761   209
# top             NaN  Sochi  Skiing  Ice Hockey  BJOERNDALEN, Ole Einar   USA
# freq            NaN    612    1781        1536                      13   653
# mean    1986.350433    NaN     NaN         NaN                     NaN   NaN
# std       24.263673    NaN     NaN         NaN                     NaN   NaN
# min     1924.000000    NaN     NaN         NaN                     NaN   NaN
# 25%     1972.000000    NaN     NaN         NaN                     NaN   NaN
# 50%     1994.000000    NaN     NaN         NaN                     NaN   NaN
# 75%     2006.000000    NaN     NaN         NaN                     NaN   NaN
# max     2014.000000    NaN     NaN         NaN                     NaN   NaN
#
#        Gender       Event   Medal        Country    Population  GDP per Capita
# count    5770        5770    5770           4990  4.985000e+03     4956.000000
# unique      2          83       3            201           NaN             NaN
# top       Men  Ice Hockey  Silver  United States           NaN             NaN
# freq     3944        1536    1930            653           NaN             NaN
# mean      NaN         NaN     NaN            NaN  9.536055e+07    44738.744452
# std       NaN         NaN     NaN            NaN  1.953490e+08    19271.499099
# min       NaN         NaN     NaN            NaN  1.022200e+04      277.068309
# 25%       NaN         NaN     NaN            NaN  8.286976e+06    41313.313995
# 50%       NaN         NaN     NaN            NaN  3.585177e+07    43248.529909
# 75%       NaN         NaN     NaN            NaN  8.141314e+07    56115.718426
# max       NaN         NaN     NaN            NaN  1.371220e+09   101449.968168

# %%
winter.describe()
# Out:
#               Year    Population  GDP per Capita
# count  5770.000000  4.985000e+03     4956.000000
# mean   1986.350433  9.536055e+07    44738.744452
# std      24.263673  1.953490e+08    19271.499099
# min    1924.000000  1.022200e+04      277.068309
# 25%    1972.000000  8.286976e+06    41313.313995
# 50%    1994.000000  3.585177e+07    43248.529909
# 75%    2006.000000  8.141314e+07    56115.718426
# max    2014.000000  1.371220e+09   101449.968168

# %%
winter.nunique()
# Out:
# Year                22
# City                19
# Sport                7
# Discipline          15
# Athlete           3761
# Code               209
# Gender               2
# Event               83
# Medal                3
# Country            201
# Population         196
# GDP per Capita     176
# dtype: int64

# %%
winter.describe(include='O')
# Out:
#          City   Sport  Discipline                 Athlete  Code Gender  \
# count    5770    5770        5770                    5770  5934   5770
# unique     19       7          15                    3761   209      2
# top     Sochi  Skiing  Ice Hockey  BJOERNDALEN, Ole Einar   USA    Men
# freq      612    1781        1536                      13   653   3944
#
#              Event   Medal        Country
# count         5770    5770           4990
# unique          83       3            201
# top     Ice Hockey  Silver  United States
# freq          1536    1930            653

# %% [markdown]
# ### Medal Distribution in top 10 countries [Winter Olympics]:

# %%
medals_country = winter.groupby(['Country', 'Medal'])['Gender'].count().reset_index().sort_values(by='Gender', ascending=False)

# %%
medals_country
# Out:
#           Country   Medal  Gender
# 97  United States  Silver     319
# 16         Canada    Gold     315
# 31        Finland  Bronze     221
# 17         Canada  Silver     203
# 83         Sweden  Bronze     177
# ..            ...     ...     ...
# 51   Korea, North  Bronze       1
# 28        Estonia  Bronze       1
# 21        Croatia  Bronze       1
# 13       Bulgaria    Gold       1
# 98     Uzbekistan    Gold       1
#
# [99 rows x 3 columns]

# %%
top = medals_country.pivot('Country', 'Medal', 'Gender').fillna(0)

# %%
top
# Out:
# Medal           Bronze   Gold  Silver
# Country
# Australia          7.0    5.0     3.0
# Austria          103.0   79.0    98.0
# Belarus            5.0    6.0     4.0
# Belgium            7.0    2.0     4.0
# Bulgaria           3.0    1.0     2.0
# Canada           107.0  315.0   203.0
# China             36.0   16.0    30.0
# Croatia            1.0    4.0     6.0
# Czech Republic    35.0   28.0    12.0
# Denmark            0.0    0.0     5.0
# Estonia            1.0    4.0     2.0
# Finland          221.0   66.0   147.0
# France            81.0   36.0    35.0
# Germany           97.0  137.0   126.0
# Hungary            8.0    0.0     4.0
# Italy             77.0   58.0    57.0
# Japan             24.0   17.0    22.0
# Kazakhstan         3.0    1.0     3.0
# Korea, North       1.0    0.0     1.0
# Korea, South      10.0   51.0    26.0
# Latvia             7.0    0.0     8.0
# Liechtenstein      5.0    2.0     2.0
# Luxembourg         0.0    0.0     2.0
# Netherlands       42.0   42.0    38.0
# New Zealand        0.0    0.0     1.0
# Norway           127.0  159.0   171.0
# Poland            11.0    6.0    10.0
# Russia            79.0   94.0    90.0
# Slovakia           1.0    2.0     2.0
# Slovenia          12.0    2.0     4.0
# Spain              1.0    1.0     0.0
# Sweden           177.0  127.0   129.0
# Switzerland      132.0   76.0    77.0
# Ukraine            5.0    5.0     1.0
# United Kingdom    34.0   34.0    11.0
# United States    167.0  167.0   319.0
# Uzbekistan         0.0    1.0     0.0

# %%
top = top.sort_values(by='Gold', ascending=False)[:10]

# %%
top
# Out:
# Medal          Bronze   Gold  Silver
# Country
# Canada          107.0  315.0   203.0
# United States   167.0  167.0   319.0
# Norway          127.0  159.0   171.0
# Germany          97.0  137.0   126.0
# Sweden          177.0  127.0   129.0
# Russia           79.0   94.0    90.0
# Austria         103.0   79.0    98.0
# Switzerland     132.0   76.0    77.0
# Finland         221.0   66.0   147.0
# Italy            77.0   58.0    57.0

# %% [markdown]
# #### Data Visulization

# %%
fig = top.plot.barh(width=0.8)
fig = plt.gcf()
fig.set_size_inches(12,12)
plt.title('Medals Distribution for top 10 countries [Winter Olympics]')
plt.show()

# %% [markdown]
# # Analyzing the Summer Data

# %%
summer.rename(columns={'Country' : 'Code'}, inplace=True)

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Code Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer = pd.merge(summer, dict, on='Code', how='outer')

# %%
summer.head()
# Out:
#      Year    City      Sport Discipline           Athlete Code Gender  \
# 0  1896.0  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 1  1896.0  Athens   Aquatics   Swimming     HAJOS, Alfred  HUN    Men
# 2  1896.0  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men
# 3  1896.0  Athens  Athletics  Athletics      DANI, Nandor  HUN    Men
# 4  1896.0  Athens  Athletics  Athletics    KELLNER, Gyula  HUN    Men
#
#              Event   Medal  Country  Population  GDP per Capita
# 0   100M Freestyle    Gold  Hungary   9844686.0     12363.54346
# 1  1200M Freestyle    Gold  Hungary   9844686.0     12363.54346
# 2             100M  Bronze  Hungary   9844686.0     12363.54346
# 3             800M  Silver  Hungary   9844686.0     12363.54346
# 4         Marathon  Bronze  Hungary   9844686.0     12363.54346

# %%
summer.describe()
# Out:
#                Year    Population  GDP per Capita
# count  31165.000000  2.576600e+04    25200.000000
# mean    1970.482785  1.482346e+08    36746.158771
# std       33.158416  2.669055e+08    19584.821782
# min     1896.000000  1.022200e+04      277.068309
# 25%     1948.000000  1.138956e+07    16088.277587
# 50%     1980.000000  6.080208e+07    41313.313995
# 75%     2000.000000  1.440968e+08    56115.718426
# max     2012.000000  1.371220e+09   101449.968168

# %%
summer.nunique()
# Out:
# Year                 27
# City                 22
# Sport                43
# Discipline           67
# Athlete           22762
# Code                219
# Gender                2
# Event               666
# Medal                 3
# Country             201
# Population          196
# GDP per Capita      176
# dtype: int64

# %%
summer.describe(include=['O'])
# Out:
#           City     Sport Discipline          Athlete   Code Gender     Event  \
# count    31165     31165      31165            31165  31233  31165     31165
# unique      22        43         67            22762    219      2       666
# top     London  Aquatics  Athletics  PHELPS, Michael    USA    Men  Football
# freq      3567      4170       3638               22   4585  22746      1497
#
#         Medal        Country
# count   31165          25814
# unique      3            201
# top      Gold  United States
# freq    10486           4585

# %% [markdown]
# # Who won the most medals

# %%
medals = summer.groupby(['Athlete', 'Medal'])['Sport'].count().reset_index().sort_values(by='Sport', ascending=False)

# %%
medals
# Out:
#                    Athlete   Medal  Sport
# 18383      PHELPS, Michael    Gold     18
# 13465          LEWIS, Carl    Gold      9
# 17060         NURMI, Paavo    Gold      9
# 22145          SPITZ, Mark    Gold      9
# 13061     LATYNINA, Larisa    Gold      9
# ...                    ...     ...    ...
# 9498         HODGES, Laura  Bronze      1
# 9497          HODGE, Percy    Gold      1
# 9496          HODGE, Megan  Silver      1
# 9495   HODGE, Daniel Allen  Silver      1
# 26723    ÖSTRAND, Per-Olof  Bronze      1
#
# [26724 rows x 3 columns]

# %% [markdown]
# # Medal Distribution in top 10 countries [Summer Olympics]:

# %%
medals_country = summer.groupby(['Country', 'Medal'])['Gender'].count().reset_index().sort_values(by='Gender', 
                                                                                                  ascending=False)

# %%
medals_country
# Out:
#                  Country   Medal  Gender
# 283        United States    Gold    2235
# 284        United States  Silver    1252
# 282        United States  Bronze    1098
# 281       United Kingdom  Silver     621
# 279       United Kingdom  Bronze     553
# ..                   ...     ...     ...
# 264  Trinidad and Tobago    Gold       1
# 75               Ecuador    Gold       1
# 166           Luxembourg    Gold       1
# 132               Israel    Gold       1
# 72    Dominican Republic  Bronze       1
#
# [301 rows x 3 columns]

# %%
medals_country = medals_country.pivot('Country', 'Medal', 'Gender').fillna(0)

# %%
medals_country
# Out:
# Medal            Bronze   Gold  Silver
# Country
# Afghanistan         2.0    0.0     0.0
# Algeria             8.0    5.0     2.0
# Argentina          91.0   69.0    99.0
# Armenia             8.0    1.0     2.0
# Australia         472.0  312.0   405.0
# ...                 ...    ...     ...
# Venezuela           8.0    2.0     2.0
# Vietnam             0.0    0.0     2.0
# Virgin Islands*     0.0    0.0     1.0
# Zambia              1.0    0.0     1.0
# Zimbabwe            1.0   18.0     4.0
#
# [129 rows x 3 columns]

# %%
top = medals_country.sort_values(by='Gold', ascending=False)[:10]

# %%
top
# Out:
# Medal           Bronze    Gold  Silver
# Country
# United States   1098.0  2235.0  1252.0
# United Kingdom   553.0   546.0   621.0
# Italy            404.0   476.0   416.0
# Germany          475.0   452.0   378.0
# Hungary          351.0   412.0   316.0
# France           497.0   408.0   491.0
# Sweden           328.0   349.0   367.0
# Australia        472.0   312.0   405.0
# China            221.0   290.0   296.0
# Russia           291.0   239.0   238.0

# %% [markdown]
# #### Data Visulization

# %%
fig = top.plot.barh(width=0.8)
fig = plt.gcf()
fig.set_size_inches(12,12)
plt.title("Medals Distribution in top 10 countries")
plt.show()
